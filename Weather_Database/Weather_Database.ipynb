# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
# Url plus your API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e65cf662f02f0b5b554ea5aaabadca98

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | necochea
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | kavieng
# Processing Record 5 of Set 1 | lata
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | vardo
# Processing Record 9 of Set 1 | muisne
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | pangnirtung
# Processing Record 13 of Set 1 | geraldton
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | marshall
# Processing Record 16 of Set 1 | guajara-mirim
# City not found. Skipping...
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | mahalapye
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | turayf
# Processing Record 24 of Set 1 | garowe
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | ust-nera
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | vaitape
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | oktyabrskoye
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | ust-tsilma
# Processing Record 43 of Set 1 | castlegar
# Processing Record 44 of Set 1 | colombo
# Processing Record 45 of Set 1 | leningradskiy
# Processing Record 46 of Set 1 | kieta
# Processing Record 47 of Set 1 | bairiki
# Processing Record 48 of Set 1 | tautira
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | kavaratti
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | maragogi
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | touros
# Processing Record 5 of Set 2 | glazunovka
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | asau
# Processing Record 9 of Set 2 | ambon
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | anadyr
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | ouargaye
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | sao jose da coroa grande
# Processing Record 16 of Set 2 | sterling
# Processing Record 17 of Set 2 | qafsah
# City not found. Skipping...
# Processing Record 18 of Set 2 | novikovo
# Processing Record 19 of Set 2 | isangel
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | providencia
# Processing Record 22 of Set 2 | trincomalee
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | quthing
# Processing Record 26 of Set 2 | arya
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | port lincoln
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | bambous virieux
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | beloha
# Processing Record 34 of Set 2 | inverell
# Processing Record 35 of Set 2 | harper
# Processing Record 36 of Set 2 | boyabat
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 2 | chipata
# Processing Record 41 of Set 2 | skorodnoye
# Processing Record 42 of Set 2 | nalut
# Processing Record 43 of Set 2 | rosita
# Processing Record 44 of Set 2 | kodinar
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | loubomo
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | ocos
# Processing Record 49 of Set 2 | adeje
# Processing Record 50 of Set 2 | smithers
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | rabo de peixe
# Processing Record 3 of Set 3 | kurchum
# Processing Record 4 of Set 3 | santa helena de goias
# Processing Record 5 of Set 3 | kumano
# Processing Record 6 of Set 3 | puerto penasco
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | upington
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | wagar
# Processing Record 12 of Set 3 | tias
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | namatanai
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 3 | taksimo
# Processing Record 18 of Set 3 | road town
# Processing Record 19 of Set 3 | ornskoldsvik
# Processing Record 20 of Set 3 | daru
# Processing Record 21 of Set 3 | kununurra
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | poronaysk
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | port alfred
# Processing Record 26 of Set 3 | sioux lookout
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | naugarzan
# City not found. Skipping...
# Processing Record 30 of Set 3 | shimoda
# Processing Record 31 of Set 3 | ouro preto do oeste
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | shingu
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | ambulu
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | port-cartier
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | broome
# Processing Record 45 of Set 3 | pokhvistnevo
# Processing Record 46 of Set 3 | kyren
# Processing Record 47 of Set 3 | sisimiut
# Processing Record 48 of Set 3 | kabanjahe
# Processing Record 49 of Set 3 | prenzlau
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | ushtobe
# Processing Record 4 of Set 4 | ocampo
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | marihatag
# Processing Record 7 of Set 4 | norman wells
# Processing Record 8 of Set 4 | braniewo
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 4 | quelimane
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | vallenar
# Processing Record 14 of Set 4 | biscarrosse
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | mutenice
# Processing Record 17 of Set 4 | nanfeng
# Processing Record 18 of Set 4 | kislovodsk
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | guira de melena
# Processing Record 23 of Set 4 | fort nelson
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | shihezi
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | matay
# Processing Record 29 of Set 4 | el carrizo
# Processing Record 30 of Set 4 | rassvet
# Processing Record 31 of Set 4 | pacifica
# Processing Record 32 of Set 4 | naze
# Processing Record 33 of Set 4 | tokur
# Processing Record 34 of Set 4 | andreyevka
# Processing Record 35 of Set 4 | qaanaaq
# Processing Record 36 of Set 4 | pergamino
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 4 | nizhniy tsasuchey
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | beyneu
# Processing Record 42 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 4 | contai
# Processing Record 44 of Set 4 | buchanan
# Processing Record 45 of Set 4 | celestun
# Processing Record 46 of Set 4 | tooele
# Processing Record 47 of Set 4 | komsomolskiy
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | umm kaddadah
# Processing Record 50 of Set 4 | bredasdorp
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | lasa
# Processing Record 3 of Set 5 | hailey
# Processing Record 4 of Set 5 | diamantino
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | mehamn
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 5 | xichang
# Processing Record 11 of Set 5 | banjar
# Processing Record 12 of Set 5 | kuching
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | natal
# Processing Record 15 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | impfondo
# Processing Record 18 of Set 5 | bintulu
# Processing Record 19 of Set 5 | benguela
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | amapa
# Processing Record 22 of Set 5 | karasjok
# Processing Record 23 of Set 5 | mahur
# Processing Record 24 of Set 5 | dori
# Processing Record 25 of Set 5 | atasu
# Processing Record 26 of Set 5 | bluff
# Processing Record 27 of Set 5 | port elizabeth
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | caiaponia
# Processing Record 30 of Set 5 | kachug
# Processing Record 31 of Set 5 | chokurdakh
# Processing Record 32 of Set 5 | jasper
# Processing Record 33 of Set 5 | inta
# Processing Record 34 of Set 5 | arlit
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | tessalit
# Processing Record 37 of Set 5 | hit
# Processing Record 38 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 5 | okha
# Processing Record 40 of Set 5 | russell
# Processing Record 41 of Set 5 | castro
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | palmer
# Processing Record 44 of Set 5 | portland
# Processing Record 45 of Set 5 | hun
# Processing Record 46 of Set 5 | belaya gora
# Processing Record 47 of Set 5 | pevek
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | chifeng
# Processing Record 50 of Set 5 | maningrida
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | mahebourg
# Processing Record 3 of Set 6 | puerto ayora
# Processing Record 4 of Set 6 | newport
# Processing Record 5 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 6 | ulladulla
# Processing Record 7 of Set 6 | walvis bay
# Processing Record 8 of Set 6 | weiser
# Processing Record 9 of Set 6 | barcelona
# Processing Record 10 of Set 6 | cabo san lucas
# Processing Record 11 of Set 6 | maloy
# Processing Record 12 of Set 6 | erzin
# Processing Record 13 of Set 6 | namtsy
# Processing Record 14 of Set 6 | norden
# Processing Record 15 of Set 6 | aguadilla
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | north bend
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | sao joao da barra
# Processing Record 20 of Set 6 | sao filipe
# Processing Record 21 of Set 6 | berlevag
# Processing Record 22 of Set 6 | kwekwe
# Processing Record 23 of Set 6 | port macquarie
# Processing Record 24 of Set 6 | usinsk
# Processing Record 25 of Set 6 | ostrovnoy
# Processing Record 26 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | kirillov
# Processing Record 29 of Set 6 | gizo
# Processing Record 30 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 6 | qandala
# Processing Record 32 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | yerbogachen
# Processing Record 36 of Set 6 | nizhnevartovsk
# Processing Record 37 of Set 6 | kattivakkam
# Processing Record 38 of Set 6 | iquique
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 6 | vila franca do campo
# Processing Record 42 of Set 6 | mumford
# Processing Record 43 of Set 6 | high level
# Processing Record 44 of Set 6 | anito
# Processing Record 45 of Set 6 | acapulco
# Processing Record 46 of Set 6 | grimari
# City not found. Skipping...
# Processing Record 47 of Set 6 | san policarpo
# Processing Record 48 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | new richmond
# Processing Record 50 of Set 6 | alta floresta
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | beaumont
# Processing Record 4 of Set 7 | marandahalli
# Processing Record 5 of Set 7 | bokoro
# Processing Record 6 of Set 7 | tsalka
# Processing Record 7 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | gidam
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | lahat
# Processing Record 12 of Set 7 | rio gallegos
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | pringsewu
# Processing Record 15 of Set 7 | rajanpur
# Processing Record 16 of Set 7 | kidal
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | sungaipenuh
# Processing Record 19 of Set 7 | calvinia
# Processing Record 20 of Set 7 | bud
# Processing Record 21 of Set 7 | faanui
# Processing Record 22 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | namibe
# Processing Record 25 of Set 7 | cidreira
# Processing Record 26 of Set 7 | khorixas
# Processing Record 27 of Set 7 | yaan
# Processing Record 28 of Set 7 | buhe
# Processing Record 29 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 30 of Set 7 | oswego
# Processing Record 31 of Set 7 | muli
# Processing Record 32 of Set 7 | faya
# Processing Record 33 of Set 7 | amargosa
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | manado
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | suvorov
# Processing Record 38 of Set 7 | nhulunbuy
# Processing Record 39 of Set 7 | mount isa
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | manta
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | la ciotat
# Processing Record 44 of Set 7 | gigante
# Processing Record 45 of Set 7 | phatthalung
# Processing Record 46 of Set 7 | port hedland
# Processing Record 47 of Set 7 | nioro
# Processing Record 48 of Set 7 | baraki barak
# Processing Record 49 of Set 7 | muborak
# Processing Record 50 of Set 7 | yiyang
# Processing Record 1 of Set 8 | fredericksburg
# Processing Record 2 of Set 8 | matara
# Processing Record 3 of Set 8 | huambo
# Processing Record 4 of Set 8 | loiza
# Processing Record 5 of Set 8 | changde
# Processing Record 6 of Set 8 | wanlaweyn
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | baiyin
# Processing Record 9 of Set 8 | sao joao de pirabas
# Processing Record 10 of Set 8 | emerald
# Processing Record 11 of Set 8 | santa maria
# Processing Record 12 of Set 8 | sobolevo
# Processing Record 13 of Set 8 | chamrajnagar
# Processing Record 14 of Set 8 | bethel
# Processing Record 15 of Set 8 | pacific grove
# Processing Record 16 of Set 8 | angra
# City not found. Skipping...
# Processing Record 17 of Set 8 | coruripe
# Processing Record 18 of Set 8 | labuhan
# Processing Record 19 of Set 8 | surt
# Processing Record 20 of Set 8 | quatre cocos
# Processing Record 21 of Set 8 | macusani
# Processing Record 22 of Set 8 | zalantun
# Processing Record 23 of Set 8 | sistranda
# Processing Record 24 of Set 8 | severodvinsk
# Processing Record 25 of Set 8 | atambua
# Processing Record 26 of Set 8 | yinchuan
# Processing Record 27 of Set 8 | ternovka
# Processing Record 28 of Set 8 | cherskiy
# Processing Record 29 of Set 8 | marystown
# Processing Record 30 of Set 8 | pavda
# City not found. Skipping...
# Processing Record 31 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 8 | clarence town
# Processing Record 33 of Set 8 | loandjili
# Processing Record 34 of Set 8 | ranau
# Processing Record 35 of Set 8 | pakokku
# Processing Record 36 of Set 8 | ponta delgada
# Processing Record 37 of Set 8 | nara
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 40 of Set 8 | muros
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | houma
# Processing Record 43 of Set 8 | cap-chat
# Processing Record 44 of Set 8 | bitung
# Processing Record 45 of Set 8 | gezing
# Processing Record 46 of Set 8 | bull savanna
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | canyon
# Processing Record 49 of Set 8 | koungheul
# Processing Record 50 of Set 8 | tiruvallur
# Processing Record 1 of Set 9 | los llanos de aridane
# Processing Record 2 of Set 9 | chardara
# Processing Record 3 of Set 9 | opuwo
# Processing Record 4 of Set 9 | bajil
# Processing Record 5 of Set 9 | sitka
# Processing Record 6 of Set 9 | ihtiman
# Processing Record 7 of Set 9 | hurghada
# Processing Record 8 of Set 9 | otofuke
# Processing Record 9 of Set 9 | bahia de caraquez
# Processing Record 10 of Set 9 | salima
# Processing Record 11 of Set 9 | ferrandina
# Processing Record 12 of Set 9 | mogwase
# Processing Record 13 of Set 9 | kuressaare
# Processing Record 14 of Set 9 | kiruna
# Processing Record 15 of Set 9 | padang
# Processing Record 16 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 9 | presidencia roque saenz pena
# Processing Record 18 of Set 9 | puerto madryn
# Processing Record 19 of Set 9 | port blair
# Processing Record 20 of Set 9 | boyolangu
# Processing Record 21 of Set 9 | fairview
# Processing Record 22 of Set 9 | nelson bay
# Processing Record 23 of Set 9 | frontignan
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | miraflores
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | calama
# Processing Record 28 of Set 9 | caravelas
# Processing Record 29 of Set 9 | choya
# Processing Record 30 of Set 9 | westport
# Processing Record 31 of Set 9 | kawalu
# Processing Record 32 of Set 9 | buenos aires
# Processing Record 33 of Set 9 | nsanje
# Processing Record 34 of Set 9 | naryan-mar
# Processing Record 35 of Set 9 | yulara
# Processing Record 36 of Set 9 | omboue
# Processing Record 37 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 9 | suntar
# Processing Record 39 of Set 9 | purpe
# Processing Record 40 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 9 | leshukonskoye
# Processing Record 42 of Set 9 | baruun-urt
# Processing Record 43 of Set 9 | elko
# Processing Record 44 of Set 9 | matagami
# Processing Record 45 of Set 9 | santa fe
# Processing Record 46 of Set 9 | kendari
# Processing Record 47 of Set 9 | slatina
# Processing Record 48 of Set 9 | portobelo
# Processing Record 49 of Set 9 | abu samrah
# Processing Record 50 of Set 9 | hofn
# Processing Record 1 of Set 10 | kailua
# Processing Record 2 of Set 10 | portsmouth
# Processing Record 3 of Set 10 | malatya
# Processing Record 4 of Set 10 | varhaug
# Processing Record 5 of Set 10 | tortosa
# Processing Record 6 of Set 10 | college
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | wamba
# Processing Record 9 of Set 10 | sovetskiy
# Processing Record 10 of Set 10 | jalu
# Processing Record 11 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 10 | bongouanou
# Processing Record 13 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 14 of Set 10 | oranjemund
# Processing Record 15 of Set 10 | dalbandin
# Processing Record 16 of Set 10 | yumen
# Processing Record 17 of Set 10 | beira
# Processing Record 18 of Set 10 | ladario
# Processing Record 19 of Set 10 | sola
# Processing Record 20 of Set 10 | mecca
# Processing Record 21 of Set 10 | nichinan
# Processing Record 22 of Set 10 | soyo
# Processing Record 23 of Set 10 | seoul
# Processing Record 24 of Set 10 | belle fourche
# Processing Record 25 of Set 10 | neyyattinkara
# Processing Record 26 of Set 10 | waling
# Processing Record 27 of Set 10 | weligama
# Processing Record 28 of Set 10 | andenes
# Processing Record 29 of Set 10 | vestmannaeyjar
# Processing Record 30 of Set 10 | methoni
# Processing Record 31 of Set 10 | roald
# Processing Record 32 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 10 | santa vitoria do palmar
# Processing Record 34 of Set 10 | halifax
# Processing Record 35 of Set 10 | tempio pausania
# Processing Record 36 of Set 10 | price
# Processing Record 37 of Set 10 | solofra
# Processing Record 38 of Set 10 | tilichiki
# Processing Record 39 of Set 10 | frei paulo
# Processing Record 40 of Set 10 | nikolayevka
# Processing Record 41 of Set 10 | saint-michel-des-saints
# Processing Record 42 of Set 10 | antofagasta
# Processing Record 43 of Set 10 | swan hill
# Processing Record 44 of Set 10 | moose factory
# Processing Record 45 of Set 10 | rexburg
# Processing Record 46 of Set 10 | eirunepe
# Processing Record 47 of Set 10 | bay roberts
# Processing Record 48 of Set 10 | kasangulu
# Processing Record 49 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 10 | pskov
# Processing Record 1 of Set 11 | prince rupert
# Processing Record 2 of Set 11 | lang son
# Processing Record 3 of Set 11 | mikhaylovsk
# Processing Record 4 of Set 11 | olafsvik
# Processing Record 5 of Set 11 | mahabad
# Processing Record 6 of Set 11 | kaeo
# Processing Record 7 of Set 11 | zachary
# Processing Record 8 of Set 11 | mwandiga
# Processing Record 9 of Set 11 | hay river
# Processing Record 10 of Set 11 | snyder
# Processing Record 11 of Set 11 | staritsa
# Processing Record 12 of Set 11 | meiganga
# Processing Record 13 of Set 11 | san jose
# Processing Record 14 of Set 11 | vangaindrano
# Processing Record 15 of Set 11 | kiama
# Processing Record 16 of Set 11 | saurimo
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | panama city
# Processing Record 19 of Set 11 | guia de isora
# Processing Record 20 of Set 11 | rapar
# Processing Record 21 of Set 11 | bloemfontein
# Processing Record 22 of Set 11 | tateyama
# Processing Record 23 of Set 11 | miguel alves
# Processing Record 24 of Set 11 | plymouth
# Processing Record 25 of Set 11 | luganville
# Processing Record 26 of Set 11 | caibarien
# Processing Record 27 of Set 11 | salalah
# Processing Record 28 of Set 11 | kalmar
# Processing Record 29 of Set 11 | nago
# Processing Record 30 of Set 11 | mangochi
# Processing Record 31 of Set 11 | paramonga
# Processing Record 32 of Set 11 | santa cruz de la palma
# Processing Record 33 of Set 11 | kalabo
# Processing Record 34 of Set 11 | xining
# Processing Record 35 of Set 11 | porto nacional
# Processing Record 36 of Set 11 | mamit
# Processing Record 37 of Set 11 | tahta
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | polahongon
# Processing Record 40 of Set 11 | meulaboh
# Processing Record 41 of Set 11 | olavarria
# Processing Record 42 of Set 11 | honningsvag
# Processing Record 43 of Set 11 | state college
# Processing Record 44 of Set 11 | minab
# Processing Record 45 of Set 11 | marawi
# Processing Record 46 of Set 11 | meinung
# City not found. Skipping...
# Processing Record 47 of Set 11 | blagoyevo
# Processing Record 48 of Set 11 | moranbah
# Processing Record 49 of Set 11 | krasnoarmeysk
# Processing Record 50 of Set 11 | dubti
# Processing Record 1 of Set 12 | luanda
# Processing Record 2 of Set 12 | bosilegrad
# Processing Record 3 of Set 12 | rio tuba
# Processing Record 4 of Set 12 | amuntai
# Processing Record 5 of Set 12 | nome
# Processing Record 6 of Set 12 | prado
# Processing Record 7 of Set 12 | pravia
# Processing Record 8 of Set 12 | sambava
# Processing Record 9 of Set 12 | kurtamysh
# Processing Record 10 of Set 12 | shimanovsk
# Processing Record 11 of Set 12 | christchurch
# Processing Record 12 of Set 12 | lashio
# Processing Record 13 of Set 12 | angoche
# Processing Record 14 of Set 12 | djambala
# Processing Record 15 of Set 12 | yasnyy
# Processing Record 16 of Set 12 | codrington
# Processing Record 17 of Set 12 | bontang
# Processing Record 18 of Set 12 | phalaborwa
# Processing Record 19 of Set 12 | baghdad
# Processing Record 20 of Set 12 | mareeba
# Processing Record 21 of Set 12 | uyuni
# Processing Record 22 of Set 12 | sanary-sur-mer
# Processing Record 23 of Set 12 | praia da vitoria
# Processing Record 24 of Set 12 | baft
# Processing Record 25 of Set 12 | prainha
# Processing Record 26 of Set 12 | tasiilaq
# Processing Record 27 of Set 12 | adre
# Processing Record 28 of Set 12 | bedford
# Processing Record 29 of Set 12 | gimbi
# Processing Record 30 of Set 12 | kaliganj
# Processing Record 31 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 12 | pimentel
# Processing Record 33 of Set 12 | liwale
# Processing Record 34 of Set 12 | koundara
# Processing Record 35 of Set 12 | darhan
# Processing Record 36 of Set 12 | diego de almagro
# Processing Record 37 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 38 of Set 12 | kosh-agach
# Processing Record 39 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 12 | nizhneangarsk
# Processing Record 41 of Set 12 | olinda
# Processing Record 42 of Set 12 | mahenge
# Processing Record 43 of Set 12 | znamenskoye
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | nayagarh
# Processing Record 46 of Set 12 | shelbyville
# Processing Record 47 of Set 12 | rorvik
# Processing Record 48 of Set 12 | rodrigues alves
# Processing Record 49 of Set 12 | imst
# Processing Record 50 of Set 12 | chara
# Processing Record 1 of Set 13 | ixtapa
# Processing Record 2 of Set 13 | sabang
# Processing Record 3 of Set 13 | noumea
# Processing Record 4 of Set 13 | shar
# Processing Record 5 of Set 13 | mangrol
# Processing Record 6 of Set 13 | key west
# Processing Record 7 of Set 13 | bemidji
# Processing Record 8 of Set 13 | hami
# Processing Record 9 of Set 13 | keningau
# Processing Record 10 of Set 13 | guerande
# Processing Record 11 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 12 of Set 13 | sur
# Processing Record 13 of Set 13 | lekoni
# Processing Record 14 of Set 13 | kovernino
# Processing Record 15 of Set 13 | balabac
# Processing Record 16 of Set 13 | mozarlandia
# Processing Record 17 of Set 13 | mayo
# Processing Record 18 of Set 13 | bozeman
# Processing Record 19 of Set 13 | dali
# Processing Record 20 of Set 13 | gorontalo
# Processing Record 21 of Set 13 | lagoa da canoa
# Processing Record 22 of Set 13 | kincardine
# Processing Record 23 of Set 13 | thinadhoo
# Processing Record 24 of Set 13 | shenjiamen
# Processing Record 25 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 13 | nerchinsk
# Processing Record 27 of Set 13 | port hardy
# Processing Record 28 of Set 13 | carutapera
# Processing Record 29 of Set 13 | ekhabi
# Processing Record 30 of Set 13 | kulhudhuffushi
# Processing Record 31 of Set 13 | grootfontein
# Processing Record 32 of Set 13 | humaita
# Processing Record 33 of Set 13 | nao-me-toque
# City not found. Skipping...
# Processing Record 34 of Set 13 | vao
# Processing Record 35 of Set 13 | acara
# Processing Record 36 of Set 13 | domoni
# Processing Record 37 of Set 13 | qasigiannguit
# Processing Record 38 of Set 13 | ust-barguzin
# Processing Record 39 of Set 13 | kasamwa
# Processing Record 40 of Set 13 | paamiut
# Processing Record 41 of Set 13 | alekseyevsk
# Processing Record 42 of Set 13 | nagram
# Processing Record 43 of Set 13 | reynoldsburg
# Processing Record 44 of Set 13 | trairi
# Processing Record 45 of Set 13 | erbaa
# Processing Record 46 of Set 13 | mayumba
# Processing Record 47 of Set 13 | churapcha
# Processing Record 48 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 13 | little current
# Processing Record 50 of Set 13 | berdigestyakh
# Processing Record 1 of Set 14 | miesbach
# Processing Record 2 of Set 14 | cotonou
# Processing Record 3 of Set 14 | puerto escondido
# Processing Record 4 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 14 | tartagal
# Processing Record 6 of Set 14 | lamar
# Processing Record 7 of Set 14 | sao felix do xingu
# Processing Record 8 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 14 | kutum
# Processing Record 10 of Set 14 | beboto
# Processing Record 11 of Set 14 | torrington
# Processing Record 12 of Set 14 | sri aman
# Processing Record 13 of Set 14 | goderich
# Processing Record 14 of Set 14 | la libertad
# Processing Record 15 of Set 14 | chapais
# Processing Record 16 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 14 | paragominas
# Processing Record 18 of Set 14 | devonport
# Processing Record 19 of Set 14 | bowen
# Processing Record 20 of Set 14 | havelock
# Processing Record 21 of Set 14 | tifton
# Processing Record 22 of Set 14 | kharp
# Processing Record 23 of Set 14 | phangnga
# Processing Record 24 of Set 14 | khuzhir
# Processing Record 25 of Set 14 | warwick
# Processing Record 26 of Set 14 | soc trang
# Processing Record 27 of Set 14 | kalmunai
# Processing Record 28 of Set 14 | seydisehir
# Processing Record 29 of Set 14 | skeldon
# Processing Record 30 of Set 14 | margate
# Processing Record 31 of Set 14 | rio grande
# Processing Record 32 of Set 14 | arvika
# Processing Record 33 of Set 14 | kazanskoye
# Processing Record 34 of Set 14 | taua
# Processing Record 35 of Set 14 | hereford
# Processing Record 36 of Set 14 | mlowo
# Processing Record 37 of Set 14 | teya
# Processing Record 38 of Set 14 | katherine
# Processing Record 39 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 40 of Set 14 | northam
# Processing Record 41 of Set 14 | nishihara
# Processing Record 42 of Set 14 | coquimbo
# Processing Record 43 of Set 14 | san rafael
# Processing Record 44 of Set 14 | sredniy ikorets
# Processing Record 45 of Set 14 | salamiyah
# Processing Record 46 of Set 14 | kennett
# Processing Record 47 of Set 14 | synya
# Processing Record 48 of Set 14 | orvieto
# Processing Record 49 of Set 14 | cairns
# Processing Record 50 of Set 14 | carmen
# Processing Record 1 of Set 15 | kuytun
# Processing Record 2 of Set 15 | nyurba
# Processing Record 3 of Set 15 | kimbe
# Processing Record 4 of Set 15 | egvekinot
# Processing Record 5 of Set 15 | marzuq
# Processing Record 6 of Set 15 | la ronge
# Processing Record 7 of Set 15 | mayor pablo lagerenza
# Processing Record 8 of Set 15 | grenfell
# Processing Record 9 of Set 15 | dryden
# Processing Record 10 of Set 15 | hanmer springs
# Processing Record 11 of Set 15 | labuan
# Processing Record 12 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 15 | lorengau
# Processing Record 14 of Set 15 | zabaykalsk
# Processing Record 15 of Set 15 | kijabe
# Processing Record 16 of Set 15 | tibu
# Processing Record 17 of Set 15 | boffa
# Processing Record 18 of Set 15 | nizwa
# Processing Record 19 of Set 15 | murwara
# Processing Record 20 of Set 15 | virginia beach
# Processing Record 21 of Set 15 | billings
# Processing Record 22 of Set 15 | iqaluit
# Processing Record 23 of Set 15 | bambanglipuro
# Processing Record 24 of Set 15 | borovoy
# Processing Record 25 of Set 15 | vanavara
# Processing Record 26 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 27 of Set 15 | aksha
# Processing Record 28 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 29 of Set 15 | yeehaw junction
# City not found. Skipping...
# Processing Record 30 of Set 15 | najran
# Processing Record 31 of Set 15 | contamana
# Processing Record 32 of Set 15 | codajas
# Processing Record 33 of Set 15 | estelle
# Processing Record 34 of Set 15 | mackay
# Processing Record 35 of Set 15 | burnie
# Processing Record 36 of Set 15 | chernyshevskiy
# Processing Record 37 of Set 15 | gorodishche
# Processing Record 38 of Set 15 | riohacha
# Processing Record 39 of Set 15 | iralaya
# Processing Record 40 of Set 15 | chemal
# Processing Record 41 of Set 15 | masumbwe
# Processing Record 42 of Set 15 | spisska nova ves
# Processing Record 43 of Set 15 | kashi
# Processing Record 44 of Set 15 | genhe
# Processing Record 45 of Set 15 | chongwe
# Processing Record 46 of Set 15 | bonavista
# Processing Record 47 of Set 15 | hailar
# Processing Record 48 of Set 15 | bom jesus do galho
# Processing Record 49 of Set 15 | jagdalpur
# Processing Record 50 of Set 15 | gat
# Processing Record 1 of Set 16 | nuuk
# Processing Record 2 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 16 | lazaro cardenas
# Processing Record 4 of Set 16 | hermiston
# Processing Record 5 of Set 16 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 16 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 16 | bang saphan
# Processing Record 8 of Set 16 | kosovska mitrovica
# Processing Record 9 of Set 16 | ossora
# Processing Record 10 of Set 16 | havre-saint-pierre
# Processing Record 11 of Set 16 | asyut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Necochea -38.5473  -58.7368     50.18        75         100        7.23
# 1        Kapaa  22.0752 -159.3190     84.18        72          75       12.66
# 2        Airai  -8.9266  125.4092     71.11        53          45        4.29
# 3      Kavieng  -2.5744  150.7967     85.28        63          90        9.84
# 4         Lata  40.1629   -8.3327     70.02        56           0        3.62
# 5  East London -33.0153   27.9116     56.34        63           9       16.31
# 6   Kaitangata -46.2817  169.8464     43.74        89          99        9.64
# 7        Vardo  70.3705   31.1107     51.78        93         100       11.50
# 8       Muisne   0.6000  -80.0333     74.73        86          96        8.75
# 9   Nikolskoye  59.7035   30.7861     55.80        97           7        4.81
#
#   Country       Description                 Date
# 0      AR   overcast clouds  2022-07-31 02:30:00
# 1      US     broken clouds  2022-07-31 02:31:37
# 2      TL  scattered clouds  2022-07-31 02:26:47
# 3      PG   overcast clouds  2022-07-31 02:31:38
# 4      PT         clear sky  2022-07-31 02:22:42
# 5      ZA         clear sky  2022-07-31 02:31:38
# 6      NZ   overcast clouds  2022-07-31 02:31:39
# 7      NO              mist  2022-07-31 02:30:44
# 8      EC   overcast clouds  2022-07-31 02:31:39
# 9      RU         clear sky  2022-07-31 02:25:23

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Necochea -38.5473  -58.7368     50.18        75         100
# 1                 Kapaa  22.0752 -159.3190     84.18        72          75
# 2                 Airai  -8.9266  125.4092     71.11        53          45
# 3               Kavieng  -2.5744  150.7967     85.28        63          90
# 4                  Lata  40.1629   -8.3327     70.02        56           0
# ..                  ...      ...       ...       ...       ...         ...
# 692         Bang Saphan  11.2126   99.5117     85.68        70         100
# 693  Kosovska Mitrovica  42.8833   20.8667     64.60        95           4
# 694              Ossora  59.2353  163.0719     56.80        80          96
# 695  Havre-Saint-Pierre  50.2334  -63.5986     57.56        94         100
# 696               Asyut  27.1810   31.1837     77.18        25           0
#
#      Wind Speed Country       Description                 Date
# 0          7.23      AR   overcast clouds  2022-07-31 02:30:00
# 1         12.66      US     broken clouds  2022-07-31 02:31:37
# 2          4.29      TL  scattered clouds  2022-07-31 02:26:47
# 3          9.84      PG   overcast clouds  2022-07-31 02:31:38
# 4          3.62      PT         clear sky  2022-07-31 02:22:42
# ..          ...     ...               ...                  ...
# 692        7.38      TH   overcast clouds  2022-07-31 02:51:25
# 693        5.01      XK         clear sky  2022-07-31 02:51:26
# 694       13.62      RU        light rain  2022-07-31 02:51:26
# 695       14.97      CA   overcast clouds  2022-07-31 02:51:27
# 696        5.70      EG         clear sky  2022-07-31 02:51:27
#
# [697 rows x 10 columns]
